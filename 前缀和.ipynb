# %%
x_list = [1,2,3,4,5,6,7,8]

n = len(x_list)

perfix_sum = [0] * (n+1)

for i in range(n):
    perfix_sum[i+1] = perfix_sum[i] + x_list[i]
    
print(perfix_sum)

# [3,5]
left = 3
right = 5
print(perfix_sum[right] - perfix_sum[left-1])
# Out:
# [0, 1, 3, 6, 10, 15, 21, 28, 36]
# 12
